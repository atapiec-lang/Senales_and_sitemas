# %% [markdown]
# <a href="https://colab.research.google.com/github/atapiec-lang/Senales_and_sitemas/blob/main/certificados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Anderson Tapie - Intro to Programming.png](data:image/png;base64,...)

# %% [markdown]
# ![Anderson Tapie - Python (1).png](data:image/png;base64,...)
